# %%
import sys
sys.version_info
# Out:
# sys.version_info(major=3, minor=4, micro=5, releaselevel='final', serial=0)

# %%
import tensorflow as tf
tf.__version__
# Out:
# '0.12.1'

# %%
# !pip install "numpy>=1.11.0" "matplotlib>=1.5.1" "scikit-image>=0.11.3" "scikit-learn>=0.17"
# Out:
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.4/site-packages
# Requirement already satisfied: matplotlib>=1.5.1 in /usr/local/lib/python3.4/site-packages
# Requirement already satisfied: scikit-image>=0.11.3 in /usr/local/lib/python3.4/site-packages
# Requirement already satisfied: scikit-learn>=0.17 in /usr/local/lib/python3.4/site-packages
# Requirement already satisfied: cycler in /usr/local/lib/python3.4/site-packages (from matplotlib>=1.5.1)
# Requirement already satisfied: pyparsing!=2.0.0,!=2.0.4,!=2.1.2,>=1.5.6 in /usr/local/lib/python3.4/site-packages (from matplotlib>=1.5.1)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.4/site-packages (from matplotlib>=1.5.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.4/site-packages (from matplotlib>=1.5.1)
# Requirement already satisfied: PyWavelets>=0.4.0 in /usr/local/lib/python3.4/site-packages (from scikit-image>=0.11.3)
# Requirement already satisfied: networkx>=1.8 in /usr/local/lib/python3.4/site-packages (from scikit-image>=0.11.3)
# Requirement already satisfied: scipy>=0.17.0 in /usr/local/lib/python3.4/site-packages (from scikit-image>=0.11.3)
# Requirement already satisfied: pillow>=2.1.0 in /usr/local/lib/python3.4/site-packages (from scikit-image>=0.11.3)
# Requirement already satisfied: six>=1.7.3 in /usr/local/lib/python3.4/site-packages (from scikit-image>=0.11.3)
# Requirement already satisfied: decorator>=3.4.0 in /usr/local/lib/python3.4/site-packages (from networkx>=1.8->scikit-image>=0.11.3)
# Requirement already satisfied: olefile in /usr/local/lib/python3.4/site-packages (from pillow>=2.1.0->scikit-image>=0.11.3)

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.4/site-packages
# Requirement already satisfied: olefile in /usr/local/lib/python3.4/site-packages (from Pillow)

# %%
from scipy.misc import imsave

# %%
# imports
# %matplotlib inline
# %pylab osx
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cmx
# Some additional libraries which we'll use just
# to produce some visualizations of our training
from libs.utils import montage
from libs import gif
import IPython.display as ipyd
plt.style.use('ggplot')

# Bit of formatting because I don't like the default inline code style:
from IPython.core.display import HTML
HTML("""<style> .rendered_html code { 
    padding: 2px 4px;
    color: #c7254e;
    background-color: #f9f2f4;
    border-radius: 4px;
} </style>""")
# Out:
# <style> .rendered_html code {
#     padding: 2px 4px;
#     color: #c7254e;
#     background-color: #f9f2f4;
#     border-radius: 4px;
# } </style>

# %%
from libs.datasets import MNIST
ds = MNIST()
# Out:
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
plt.imshow(ds.X[0].reshape((28, 28)))

# %%
# get first 1000 images and reshape them
imgs = ds.X[:1000].reshape((-1, 28,28))

plt.imshow(montage(imgs), cmap='gray')
