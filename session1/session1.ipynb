# %%
from libs import utils

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
files = utils.get_celeb_files()

# %%
len(files)
# Out:
# 202599

# %%
img = plt.imread(files[50])

# %%
print(img)

# %%
plt.imshow(img)

# %%
img.shape

# %%
plt.imshow(img[:, :, 0], cmap='gray')
plt.imshow(img[:, :, 1], cmap='gray')
plt.imshow(img[:, :, 2], cmap='gray')

# %%
files10 = files[:10]

# %%
files10
# Out:
# ['img_align_celeba/000001.jpg',
#  'img_align_celeba/000002.jpg',
#  'img_align_celeba/000003.jpg',
#  'img_align_celeba/000004.jpg',
#  'img_align_celeba/000005.jpg',
#  'img_align_celeba/000006.jpg',
#  'img_align_celeba/000007.jpg',
#  'img_align_celeba/000008.jpg',
#  'img_align_celeba/000009.jpg',
#  'img_align_celeba/000010.jpg']

# %%
images = [plt.imread(f_i) for f_i in files10]

# %%
len(images)
# Out:
# 10

# %%
plt.imshow(images[3])

# %%
images = [plt.imread(f_i) for f_i in files[:50]]

# %%
plt.imshow(images[36])

# %%
images = [plt.imread(f_i) for f_i in files[:100]]

# %%
# MEAN IMAGE

# %%
data = np.array(images)
print(data.shape)
# Out:
# (100, 218, 178, 3)

# %%
mean_image = np.mean(images, axis=0)
plt.imshow(mean_image.astype(np.uint8))

# %%
std_img = np.std(data, axis=0)
plt.imshow(std_img.astype(np.uint8))

# %%
plt.imshow(np.mean(std_img, axis=2).astype(np.uint8))

# %%
flattened = data.ravel()
print(data[:1])
print(flattened[0:10])
# Out:
# [[[[253 231 194]
#    [253 231 194]
#    [253 231 194]
#    ...,
#    [246 228 216]
#    [255 237 223]
#    [254 238 222]]
#
#   [[253 231 194]
#    [253 231 194]
#    [253 231 194]
#    ...,
#    [248 230 218]
#    [255 237 223]
#    [254 238 222]]
#
#   [[253 231 194]
#    [253 231 194]
#    [253 231 194]
#    ...,
#    [250 232 220]
#    [255 238 224]
#    [255 239 223]]
#
#   ...,
#   [[140  74  26]
#    [115  49   1]
#    [146  78  33]
#    ...,
#    [122  55  28]
#    [123  56  30]
#    [122  56  30]]
#
#   [[130  62  15]
#    [138  70  23]
#    [166  98  53]
#    ...,
#    [118  49  20]
#    [120  50  24]
#    [118  51  24]]
#
#   [[168 100  53]
#    [204 136  89]
#    [245 177 132]
#    ...,
#    [118  49  20]
#    [120  50  24]
#    [120  50  24]]]]
# [253 231 194 253 231 194 253 231 194 253]

# %%
plt.hist(flattened.ravel(), 255)
# Out:
# (array([ 215683.,  118606.,   99471.,   71712.,   66626.,   61991.,
#           62341.,   58347.,   56752.,   56250.,   56680.,   58598.,
#           62867.,   60671.,   59112.,   59377.,   62375.,   63608.,
#           62202.,   64642.,   63383.,   62096.,   61002.,   60649.,
#           60699.,   60159.,   59116.,   59356.,   60410.,   64301.,
#           67406.,   61663.,   59823.,   60528.,   62080.,   62145.,
#           62885.,   62685.,   62504.,   62364.,   59522.,   58812.,
#           57883.,   61380.,   63337.,   57662.,   57147.,   56385.,
#           56111.,   58100.,   56285.,   55019.,   54652.,   52441.,
#           50963.,   48996.,   47700.,   45935.,   45386.,   43596.,
#           42975.,   42894.,   42317.,   42217.,   42185.,   42588.,
#           43190.,   43020.,   43251.,   43271.,   43194.,   43061.,
#           42159.,   42320.,   41874.,   41863.,   42906.,   42433.,
#           42506.,   42391.,   42675.,   42548.,   42545.,   42574.,
# ...

# %%
plt.hist(mean_image.ravel(), 255)
# Out:
# (array([    2.,     0.,     0.,     0.,     0.,     9.,    25.,    29.,
#            32.,    44.,    46.,    39.,    48.,    58.,    30.,    39.,
#            63.,    50.,    65.,    63.,    74.,    78.,    89.,   111.,
#           101.,   121.,   103.,   116.,    99.,   155.,   173.,   210.,
#           231.,   212.,   286.,   305.,   326.,   352.,   333.,   382.,
#           399.,   383.,   388.,   454.,   531.,   569.,   655.,   662.,
#           720.,   791.,   838.,   851.,   897.,   935.,   863.,   850.,
#           815.,   821.,   818.,   849.,   932.,   849.,   855.,   836.,
#           897.,   884.,   858.,   837.,   917.,   922.,   918.,   924.,
#           936.,   964.,  1009.,  1054.,  1082.,  1113.,  1163.,  1119.,
#          1124.,  1096.,  1094.,  1089.,  1086.,  1110.,  1072.,  1111.,
#          1135.,  1186.,  1131.,  1204.,  1171.,  1180.,  1237.,  1235.,
#          1171.,  1217.,  1174.,  1167.,  1244.,  1314.,  1353.,  1483.,
# ...

# %%
bins = 20
fix, axs = plt.subplots(1, 3, figsize=(12, 6))
axs[0].hist(data[0].ravel(), bins)
axs[0].set_title('img distribution')
axs[0].set_xlim([0,255])

axs[1].hist(mean_image.ravel(), bins)
axs[1].set_title('mean distribution')
axs[1].set_xlim([0,255])

axs[2].hist(((data[0] - mean_image)/std_image).ravel(), bins)
axs[2].set_title('(image - mean)/std_image distribution')
axs[2].set_xlim([-5,5])
# Out:
# (-5, 5)

# %%
import tensorflow as tf

# %%
x = np.linspace(-3,3,100)
print(x)
print(x.shape)
print(x.dtype)
# Out:
# [-3.         -2.93939394 -2.87878788 -2.81818182 -2.75757576 -2.6969697
#  -2.63636364 -2.57575758 -2.51515152 -2.45454545 -2.39393939 -2.33333333
#  -2.27272727 -2.21212121 -2.15151515 -2.09090909 -2.03030303 -1.96969697
#  -1.90909091 -1.84848485 -1.78787879 -1.72727273 -1.66666667 -1.60606061
#  -1.54545455 -1.48484848 -1.42424242 -1.36363636 -1.3030303  -1.24242424
#  -1.18181818 -1.12121212 -1.06060606 -1.         -0.93939394 -0.87878788
#  -0.81818182 -0.75757576 -0.6969697  -0.63636364 -0.57575758 -0.51515152
#  -0.45454545 -0.39393939 -0.33333333 -0.27272727 -0.21212121 -0.15151515
#  -0.09090909 -0.03030303  0.03030303  0.09090909  0.15151515  0.21212121
#   0.27272727  0.33333333  0.39393939  0.45454545  0.51515152  0.57575758
#   0.63636364  0.6969697   0.75757576  0.81818182  0.87878788  0.93939394
#   1.          1.06060606  1.12121212  1.18181818  1.24242424  1.3030303
#   1.36363636  1.42424242  1.48484848  1.54545455  1.60606061  1.66666667
# ...

# %%
x = tf.linspace(-3.0,3.0,100)
print(x)
# Out:
# Tensor("LinSpace_1:0", shape=(100,), dtype=float32)

# %%
g = tf.get_default_graph()

# %%
[op.name for op in g.get_operations()]
# Out:
# [u'LinSpace/start',
#  u'LinSpace_1/start',
#  u'LinSpace_1/stop',
#  u'LinSpace_1/num',
#  u'LinSpace_1']

# %%
g.get_tensor_by_name('LinSpace_1:0')
# Out:
# <tf.Tensor 'LinSpace_1:0' shape=(100,) dtype=float32>

# %%
sess = tf.Session()

x_val = sess.run(x)
print(x_val)
# Out:
# [-3.         -2.939394   -2.87878799 -2.81818175 -2.75757575 -2.69696975
#  -2.63636351 -2.5757575  -2.5151515  -2.4545455  -2.3939395  -2.33333325
#  -2.27272725 -2.21212125 -2.15151501 -2.090909   -2.030303   -1.969697
#  -1.90909088 -1.84848475 -1.78787875 -1.72727275 -1.66666663 -1.6060605
#  -1.5454545  -1.4848485  -1.42424238 -1.36363626 -1.30303025 -1.24242425
#  -1.18181813 -1.12121201 -1.060606   -1.         -0.939394   -0.87878776
#  -0.81818175 -0.75757575 -0.69696951 -0.63636351 -0.5757575  -0.5151515
#  -0.4545455  -0.39393926 -0.33333325 -0.27272725 -0.21212101 -0.15151501
#  -0.090909   -0.030303    0.030303    0.09090924  0.15151525  0.21212125
#   0.27272749  0.33333349  0.3939395   0.4545455   0.5151515   0.57575774
#   0.63636374  0.69696975  0.75757599  0.81818199  0.87878799  0.939394    1.
#   1.060606    1.12121201  1.18181849  1.24242449  1.30303049  1.36363649
#   1.4242425   1.4848485   1.5454545   1.60606098  1.66666698  1.72727299
# ...

# %%
x_val = x.eval(session=sess)
print(x_val)
# Out:
# [-3.         -2.939394   -2.87878799 -2.81818175 -2.75757575 -2.69696975
#  -2.63636351 -2.5757575  -2.5151515  -2.4545455  -2.3939395  -2.33333325
#  -2.27272725 -2.21212125 -2.15151501 -2.090909   -2.030303   -1.969697
#  -1.90909088 -1.84848475 -1.78787875 -1.72727275 -1.66666663 -1.6060605
#  -1.5454545  -1.4848485  -1.42424238 -1.36363626 -1.30303025 -1.24242425
#  -1.18181813 -1.12121201 -1.060606   -1.         -0.939394   -0.87878776
#  -0.81818175 -0.75757575 -0.69696951 -0.63636351 -0.5757575  -0.5151515
#  -0.4545455  -0.39393926 -0.33333325 -0.27272725 -0.21212101 -0.15151501
#  -0.090909   -0.030303    0.030303    0.09090924  0.15151525  0.21212125
#   0.27272749  0.33333349  0.3939395   0.4545455   0.5151515   0.57575774
#   0.63636374  0.69696975  0.75757599  0.81818199  0.87878799  0.939394    1.
#   1.060606    1.12121201  1.18181849  1.24242449  1.30303049  1.36363649
#   1.4242425   1.4848485   1.5454545   1.60606098  1.66666698  1.72727299
# ...

# %%
sess.close()

# %%
print(x.get_shape())
print(x.get_shape().as_list())
# Out:
# (100,)
# [100]

# %%
# create a Gaussian Curve
mean = 0.0    # mean 
sigma = 1.0   # std deviatiob

z = (tf.exp(-1*(tf.pow(x - mean, 2.0) /
                   (2.0 * tf.pow(sigma, 2.0)))) *
     (1.0 / (sigma * tf.sqrt(2.0 * 3.1415))))

# %%
sess = tf.InteractiveSession()

# %%
result = z.eval()
plt.plot(result)

# %%
ksize = z.get_shape().as_list()[0]

z_2d = tf.matmul(tf.reshape(z, [ksize, 1]), tf.reshape(z, [1, ksize]))

plt.imshow(z_2d.eval())

# %%
from skimage import data

# %%
img = data.camera().astype(np.float32)
plt.imshow(img, cmap="gray")
print(img)
# Out:
# [[ 156.  157.  160. ...,  152.  152.  152.]
#  [ 156.  157.  159. ...,  152.  152.  152.]
#  [ 158.  157.  156. ...,  152.  152.  152.]
#  ...,
#  [ 121.  123.  126. ...,  121.  113.  111.]
#  [ 121.  123.  126. ...,  121.  113.  111.]
#  [ 121.  123.  126. ...,  121.  113.  111.]]

# %%
# for convolution if tensorflow, we need 4 dimensions, N x H x W x C

img_4d = tf.reshape(img, [1, img.shape[0], img.shape[1], 1])
print(img_4d)
# Out:
# Tensor("Reshape_2:0", shape=(1, 512, 512, 1), dtype=float32)

# %%
print(img_4d.get_shape())
print(img_4d.get_shape().as_list())
# Out:
# (1, 512, 512, 1)
# [1, 512, 512, 1]

# %%
# for convolution in tensorflow, wee need the kernel to be in size of H x W x I x O

z_shape = z_2d.get_shape().as_list()
z_4d = tf.reshape(z_2d, [z_shape[0],z_shape[1],1,1])

print(z_4d.get_shape())
# Out:
# (100, 100, 1, 1)

# %%
convolved = tf.nn.conv2d(img_4d, z_4d, strides=[1,1,1,1], padding='SAME')
res = convolved.eval()
print(res)
# Out:
# [[[[ 11683.55761719]
#    [ 12224.83398438]
#    [ 12762.63574219]
#    ...,
#    [ 11864.92089844]
#    [ 11339.77441406]
#    [ 10813.08984375]]
#
#   [[ 12220.69726562]
#    [ 12786.89355469]
#    [ 13349.45800781]
#    ...,
#    [ 12410.26269531]
#    [ 11860.96484375]
#    [ 11310.0625    ]]
#
#   [[ 12753.83789062]
#    [ 13344.77441406]
#    [ 13931.921875  ]
#    ...,
#    [ 12951.61621094]
#    [ 12378.34179688]
#    [ 11803.39550781]]
#
#   ...,
#   [[  9620.06152344]
#    [ 10067.05371094]
#    [ 10510.93554688]
#    ...,
#    [  9359.68945312]
#    [  8949.125     ]
#    [  8537.16894531]]
#
#   [[  9199.49511719]
#    [  9627.00390625]
#    [ 10051.53515625]
#    ...,
#    [  8949.17578125]
#    [  8556.5703125 ]
#    [  8162.65332031]]
#
#   [[  8778.00976562]
#    [  9185.97949219]
#    [  9591.10351562]
#    ...,
#    [  8537.52929688]
#    [  8162.94384766]
#    [  7787.12402344]]]]

# %%
plt.imshow(np.squeeze(res), cmap='gray')

# %%
xs = tf.linspace(-3.0, 3.0, ksize)
ys = tf.sin(xs)
plt.figure()
plt.plot(ys.eval())
print(ys.get_shape())
print(ys.eval())
# Out:
# (100,)
# [-0.14112    -0.20082368 -0.25978994 -0.31780246 -0.37464783 -0.43011749
#  -0.48400798 -0.53612101 -0.58626539 -0.63425708 -0.67991972 -0.72308594
#  -0.76359683 -0.8013038  -0.83606857 -0.86776316 -0.89627141 -0.92148852
#  -0.94332206 -0.96169168 -0.97653002 -0.98778254 -0.99540794 -0.99937826
#  -0.99967891 -0.99630874 -0.98928016 -0.97861898 -0.96436435 -0.94656861
#  -0.92529702 -0.90062785 -0.87265158 -0.84147096 -0.80720055 -0.76996595
#  -0.72990417 -0.68716222 -0.6418969  -0.5942747  -0.54447031 -0.49266669
#  -0.43905401 -0.38382891 -0.32719463 -0.26935887 -0.21053384 -0.15093596
#  -0.09078383 -0.03029836  0.03029836  0.09078407  0.15093619  0.21053408
#   0.26935911  0.32719484  0.38382912  0.43905401  0.49266669  0.54447055
#   0.59427488  0.64189708  0.6871624   0.72990435  0.76996613  0.80720055
#   0.84147096  0.87265158  0.90062785  0.9252972   0.94656867  0.96436441
#   0.97861904  0.98928022  0.99630874  0.99967891  0.99937826  0.99540794
# ...

# %%
ys = tf.reshape(ys, [ksize, 1])
print(ys.get_shape())
# Out:
# (100, 1)

# %%
ones = tf.ones((1, ksize))
wave = tf.matmul(ys, ones)
plt.imshow(wave.eval(), cmap='gray')

# %%
# get the Gabor kernel
gabor = tf.mul(wave, z_2d)
plt.imshow(gabor.eval(), cmap='gray')

# %%
img = tf.placeholder(tf.float32, shape=[None, None], name='img')

img_3d = tf.expand_dims(img, 2)
dims = img_3d.get_shape()
print(dims)
# Out:
# (?, ?, 1)

# %%
img_4d = tf.expand_dims(img_3d, 0)
dims = img_4d.get_shape()
print(dims)
# Out:
# (1, ?, ?, 1)

# %%
mean = tf.placeholder(tf.float32, name='mean')
sigma = tf.placeholder(tf.float32, name='sigma')
ksize = tf.placeholder(tf.int32, name='ksize')

x = tf.linspace(-3.0, 3.0, ksize)
z = (tf.exp(-1*(tf.pow(x - mean, 2.0) /
                   (2.0 * tf.pow(sigma, 2.0)))) *
      (1.0 / (sigma * tf.sqrt(2.0 * 3.1415))))

ys = tf.sin(x)
ys = tf.reshape(ys, tf.stack([ksize, 1]))
ones = tf.ones(tf.stack([1, ksize]))
wave = tf.matmul(ys, ones)
gabor = tf.multiply(wave, z_2d)
gabor_4d = tf.reshape(gabor, tf.stack([ksize, ksize, 1, 1]))

# And finally, convolve the two:
convolved = tf.nn.conv2d(img_4d, gabor_4d, strides=[1, 1, 1, 1], padding='SAME', name='convolved')
convolved_img = convolved[0, :, :, 0]

res = convolved_img.eval(feed_dict={
    img: data.camera(), mean:0.0, sigma:1.0, ksize:100})
plt.imshow(res, cmap='gray')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-103-fa2fe181f092> in <module>()
#       9
#      10 ys = tf.sin(x)
# ---> 11 ys = tf.reshape(ys, tf.stack([ksize, 1]))
#      12 ones = tf.ones(tf.stack([1, ksize]))
#      13 wave = tf.matmul(ys, ones)
#
# AttributeError: 'module' object has no attribute 'stack'
